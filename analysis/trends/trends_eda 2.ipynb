# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(14.7,5.27)})

# %%
file = pd.read_csv('../../data_collection/trends/data/monthly_interest_over_time.csv')

# %%
file.columns
# Out:
# Index(['relative_dates', 'Anonymice_date', 'Anonymice', 'Anonymice NFT_date',
#        'Anonymice NFT', 'Vox Collectibles_date', 'Vox Collectibles',
#        'Vox Collectibles NFT_date', 'Vox Collectibles NFT',
#        'Galacticapes_date',
#        ...
#        'Winter Bears NFT_date', 'Winter Bears NFT', 'Tronwars_date',
#        'Tronwars', 'Tronwars NFT_date', 'Tronwars NFT', 'Nanopass_date',
#        'Nanopass', 'Nanopass NFT_date', 'Nanopass NFT'],
#       dtype='object', length=863)

# %%
example = file[['Anonymice_date', 'Anonymice', 'Anonymice NFT_date']].copy()

# %%
example = example.set_index('Anonymice_date')

# %%
example
# Out:
#                 Anonymice Anonymice NFT_date
# Anonymice_date
# 2020-09-20              0         2020-09-20
# 2020-09-27              0         2020-09-27
# 2020-10-04              0         2020-10-04
# 2020-10-11              0         2020-10-11
# 2020-10-18              0         2020-10-18
# ...                   ...                ...
# 2021-10-24             15         2021-10-24
# 2021-10-31             39         2021-10-31
# 2021-11-07              8         2021-11-07
# 2021-11-14             30         2021-11-14
# 2021-11-21             38         2021-11-21
#
# [62 rows x 2 columns]

# %%
plt.figure()

sns.lineplot(data=example)
plt.xticks(rotation=90)
plt.xlabel("week_date")
plt.ylabel("interest")
plt.title('Anonymice interest over time')
plt.tight_layout()
plt.savefig('line_plots/demo/anonymice_solo.png')
