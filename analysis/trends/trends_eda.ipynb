# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(14.7,5.27)})

# %%
file = pd.read_csv('../../data_collection/trends/data/daily_interest.csv')

# %%
file.columns
# Out:
# Index(['Unnamed: 0', 'Anonymice', 'Anonymice_date', 'Anonymice NFT',
#        'Anonymice NFT_date', 'Vox Collectibles', 'Vox Collectibles_date',
#        'Vox Collectibles NFT', 'Vox Collectibles NFT_date', 'Galacticapes',
#        ...
#        'Winter Bears', 'Winter Bears_date', 'Winter Bears NFT',
#        'Winter Bears NFT_date', 'Tronwars', 'Tronwars_date', 'Tronwars NFT',
#        'Tronwars NFT_date', 'Nanopass', 'Nanopass_date'],
#       dtype='object', length=865)

# %%
example = file[['Anonymice_date', 'Anonymice', 'Anonymice NFT_date', 'Anonymice NFT']].copy()

# %%
example = example.set_index('Anonymice_date')

# %%
example['Anonymice'] = example['Anonymice'] + example['Anonymice NFT']
example = example.drop(columns=['Anonymice NFT', 'Anonymice NFT_date'])

# %%
example = example.reset_index()

# %%
example['Anonymice_date'] = example['Anonymice_date'].apply(lambda x: pd.to_datetime(x))
# example.set_index('Anonymice_date')

# %%
example
# Out:
#     Anonymice_date  Anonymice
# 0       2021-05-05          0
# 1       2021-05-06          0
# 2       2021-05-07          0
# 3       2021-05-08          0
# 4       2021-05-09          0
# ..             ...        ...
# 264     2022-01-24          0
# 265     2022-01-25          0
# 266     2022-01-26          0
# 267     2022-01-27          0
# 268     2022-01-28          0
#
# [269 rows x 2 columns]

# %%
plt.figure()

sns.lineplot(x='Anonymice_date', y='Anonymice', data=example)
plt.xticks(rotation=45)
plt.xlabel("date")
plt.ylabel("interest")
plt.title('Anonymice interest over time')
plt.tight_layout()
plt.savefig('line_plots/demo/anonymice_solo.png')
