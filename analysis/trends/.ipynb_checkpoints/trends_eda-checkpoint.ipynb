# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('../../data_collection/trends/data/monthly_interest_over_time.csv')

# %%
file.columns
# Out:
# Index(['relative_dates', 'Anonymice_date', 'Anonymice', 'Anonymice NFT_date',
#        'Anonymice NFT', 'Vox Collectibles_date', 'Vox Collectibles',
#        'Vox Collectibles NFT_date', 'Vox Collectibles NFT',
#        'Galacticapes_date',
#        ...
#        'Winter Bears NFT_date', 'Winter Bears NFT', 'Tronwars_date',
#        'Tronwars', 'Tronwars NFT_date', 'Tronwars NFT', 'Nanopass_date',
#        'Nanopass', 'Nanopass NFT_date', 'Nanopass NFT'],
#       dtype='object', length=863)

# %%
example = file[['Anonymice_date', 'Anonymice', 'Anonymice NFT_date',
       'Anonymice NFT', 'Vox Collectibles_date', 'Vox Collectibles',
       'Vox Collectibles NFT_date', 'Vox Collectibles NFT', 'Tronwars_date',
       'Tronwars', 'Tronwars NFT_date', 'Tronwars NFT']].copy()

# %%
example
# Out:
#    Anonymice_date  Anonymice Anonymice NFT_date  Anonymice NFT  \
# 0      2020-09-20          0         2020-09-20              0
# 1      2020-09-27          0         2020-09-27              0
# 2      2020-10-04          0         2020-10-04              0
# 3      2020-10-11          0         2020-10-11              0
# 4      2020-10-18          0         2020-10-18              0
# ..            ...        ...                ...            ...
# 57     2021-10-24         15         2021-10-24              0
# 58     2021-10-31         39         2021-10-31             17
# 59     2021-11-07          8         2021-11-07              0
# 60     2021-11-14         30         2021-11-14             33
# 61     2021-11-21         38         2021-11-21             16
#
#    Vox Collectibles_date  Vox Collectibles Vox Collectibles NFT_date  \
# 0             2020-08-16                 0                2020-08-16
# ...
